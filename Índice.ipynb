# %% [markdown]
# # Índice de Katas de Python
#
# 1. [Katas de Python 01 – Frecuencia de letras](Ejercicios/Katas_Python01/Katas_Python01.ipynb)
# 2. [Katas de Python 02 – Doble de cada valor](Ejercicios/Katas_Python02/Katas_Python02.ipynb)
# 3. [Katas de Python 03 – Buscar palabras con objetivo](Ejercicios/Katas_Python03/Katas_Python03.ipynb)
# 4. [Katas de Python 04 – Diferencia entre listas usando map()](Ejercicios/Katas_Python04/Katas_Python04.ipynb)
# 5. [Katas de Python 05 - Media y estado de aprobado](Ejercicios/Katas_Python05/Katas_Python05.ipynb)
# 6. [Katas de Python 06 - Factorial recursivo](Ejercicios/Katas_Python06/Katas_Python06.ipynb)
# 7. [Katas de Python 07 - Convertir tuplas a strings](Ejercicios/Katas_Python07/Katas_Python07.ipynb)
# 8. [Katas de Python 08 - División con manejo de excepciones](Ejercicios/Katas_Python08/Katas_Python08.ipynb)
# 9. [Katas de Python 09 - filtrar mascostas prohibidas](Ejercicios/Katas_Python09/Katas_Python09.ipynb)
# 10. [Katas de Python 10 - Excepciones Personalizadas (Promedio)](Ejercicios/Katas_Python10/Katas_Python10.ipynb)
# 11. [Katas de Python 11 - Validación de Edad (Rango y Tipo)](Ejercicios/Katas_Python11/Katas_Python11.ipynb)
# 12. [Katas de Python 12 - Longitud de Palabras](Ejercicios/Katas_Python12/Katas_Python12.ipynb)
# 13. [Katas de Python 13 - Generador de Tuplas (Mayúscula/Minúscula)](Ejercicios/Katas_Python13/Katas_Python13.ipynb)
# 14. [Katas de Python 14 - Filtrar por Inicial](Ejercicios/Katas_Python14/Katas_Python14.ipynb)
# 15. [Katas de Python 15 - Transformación con Lambda](Ejercicios/Katas_Python15/Katas_Python15.ipynb)
# 16. [Katas de Python 16 - Filtro de Palabras Largas](Ejercicios/Katas_Python16/Katas_Python16.ipynb)
# 17. [Katas de Python 17 - Unir Dígitos (Reduce)](Ejercicios/Katas_Python17/Katas_Python17.ipynb)
# 18. [Katas de Python 18 - Filtrado de Estructuras de Datos (JSON)](Ejercicios/Katas_Python18/Katas_Python18.ipynb)
# 19. [Katas de Python 19 - Filtrar Números Impares (Lambda)](Ejercicios/Katas_Python19/Katas_Python19.ipynb)
# 20. [Katas de Python 20 - Limpieza de Tipos de Datos](Ejercicios/Katas_Python20/Katas_Python20.ipynb)
# 21. [Katas de Python 21 - Calcular el Cubo (Lambda)](Ejercicios/Katas_Python21/Katas_Python21.ipynb)
# 22. [Katas de Python 22 - Producto Total](Ejercicios/Katas_Python22/Katas_Python22.ipynb)
# 23. [Katas de Python 23 - Unir Palabras (Concatenar) ](../Katas_Python23/Katas_Python23.ipynb)
# 24. [Katas de Python 24 - Diferencia Total (Resta en cadena) ](../Katas_Python24/Katas_Python24.ipynb)
#
#
# *(A medida que avances, aquí añadirás la Kata 04, 05, …)*
