# %% [markdown]
# # Índice de Katas de Python
#
# 1. [Kata 01 – Frecuencia de letras](Ejercicios/Katas_Python01/Katas_Python01.ipynb)
# 2. [Kata 02 – Doble de cada valor](Ejercicios/Katas_Python02/Katas_Python02.ipynb)
# 3. [Kata 03 – Buscar palabras con objetivo](Ejercicios/Katas_Python03/Katas_Python03.ipynb)
#
# *(A medida que avances, aquí añadirás la Kata 04, 05, …)*
